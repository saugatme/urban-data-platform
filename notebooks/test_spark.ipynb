# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent
sys.path.insert(0, str(PROJECT_ROOT / "src"))

from common.spark_session import get_spark

spark = get_spark()
spark.range(3).write.format("delta").mode("overwrite").save(str(PROJECT_ROOT / "data/lake/_test"))
print("read back:", spark.read.format("delta").load(str(PROJECT_ROOT / "data/lake/_test")).count())
print("OK")
# Out:
# read back: 3
# OK
